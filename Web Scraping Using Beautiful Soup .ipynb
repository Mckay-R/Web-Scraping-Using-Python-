# %%
from bs4 import BeautifulSoup
import requests
import time 
import datetime
import csv
import pandas as pd

# %%
# connect to Amazon website

URL = 'https://www.amazon.com/Python-Programming-Introduction-Computer-Science/dp/1590282752/ref=sr_1_5?dchild=1&keywords=python+%2B+textbooks+%2B+authors&qid=1629854731&sr=8-5'

headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

page = requests.get(URL, headers = headers)

soup1 = BeautifulSoup(page.content, "html.parser")

soup2 = BeautifulSoup(soup1.prettify(), "html.parser")

title = soup2.find(id='productTitle').get_text()

#title = soup2.find(class = "a-size-medium a-color-base a-text-normal").get_Text()

price = soup2.find(id = 'newBuyBoxPrice').get_text()

author = soup2.find(id = 'bylineInfo').get_text()

# %%
# Strip the output to remove white space.
price = price.strip()[1:]
title = title.strip()
author = author[2].strip()

print(title)
print(price)
#print(author)
# Out:
# Python Programming: An Introduction to Computer Science, 3rd Ed.
# 42.75

# %%
# create a Timestamp for your output to track when data was collected 
today = datetime.date.today()
print(today)
# Out:
# 2021-08-24

# %%
#Create CSV and write headers and data into the file 

header = ['Title', 'Price', 'Date']
data = [title, price, today]

#with open('AmazonPythonTextDataset.csv', 'w', newline='', encoding='UTF8') as s:
    #writer = csv.writer(s)
    #writer.writerow(header)
    #writer.writerow(data)

# %%
df = pd.read_csv(r'C:\Users\oyeni\Python Script\AmazonPythonTextDataset.csv')
df
# Out:
#                                                 Title  Price        Date
# 0   Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 1   Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 2   Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 3   Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 4   Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 5   Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 6   Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 7   Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 8   Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 9   Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 10  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 11  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 12  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 13  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 14  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 15  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 16  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 17  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 18  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 19  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 20  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 21  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 22  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 23  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 24  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 25  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 26  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 27  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 28  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 29  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 30  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 31  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 32  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 33  Python Programming: An Introduction to Compute...  42.75  2021-08-24
# 34  Python Programming: An Introduction to Compute...  42.75  2021-08-24

# %%
# Append more data

with open('AmazonPythonTextDataset.csv', 'a+', newline='', encoding='UTF8') as s:
    writer = csv.writer(s)
    writer.writerow(data)

# %%
def web_data():
    URL = 'https://www.amazon.com/Python-Programming-Introduction-Computer-Science/dp/1590282752/ref=sr_1_5?dchild=1&keywords=python+%2B+textbooks+%2B+authors&qid=1629854731&sr=8-5'
    headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}
    page = requests.get(URL, headers = headers)
    soup1 = BeautifulSoup(page.content, "html.parser")
    soup2 = BeautifulSoup(soup1.prettify(), "html.parser")
    title = soup2.find(id='productTitle').get_text()
    price = soup2.find(id = 'newBuyBoxPrice').get_text()
    price = price.strip()[1:]
    title = title.strip()
    today = datetime.date.today()
    header = ['Title', 'Price', 'Date']
    data = [title, price, today]
    with open('AmazonPythonTextDataset.csv', 'a+', newline='', encoding='UTF8') as s:
        writer = csv.writer(s)
        writer.writerow(data)

# %%
while (True):
    web_data()
    time.sleep(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-f41df649e65f> in <module>
#       1 while (True):
#       2     web_data()
# ----> 3     time.sleep(5)
#
# KeyboardInterrupt:

# %%
df = pd.read_csv(r'C:\Users\oyeni\Python Script\AmazonPythonTextDataset.csv')
df
